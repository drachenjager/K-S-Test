# %% [markdown]
# # Kolmogorov - Smirnov Test

# %%
# Step 0 - Load the Data

# Import libraries
import pandas as pd
import numpy as np
import statistics

# Load the data
file_name = "Example_K_S.xlsx"
path = "C:/Users/usuario/Downloads/"
df = pd.read_excel(path + file_name)
df.head(30)
# Out:
#     Demand of a Product
# 0                    67
# 1                    63
# 2                    33
# 3                    69
# 4                    53
# 5                    51
# 6                    49
# 7                    78
# 8                    48
# 9                    42
# 10                   72
# 11                   52
# 12                   47
# 13                   66
# 14                   58
# 15                   44
# 16                   44
# 17                   56
# 18                   28
# 19                   25
# 20                   36
# 21                   32
# 22                   61
# 23                   57
# 24                   38
# 25                   35
# 26                   76
# 27                   58
# 28                   48
# 29                   59

# %%
# Step 1 - Order the data

df_1 = df.sort_values(by = "Demand of a Product") #ascending = True)
df_1.head()
# Out:
#     Demand of a Product
# 19                   25
# 18                   28
# 21                   32
# 2                    33
# 25                   35

# %%
# Step 2 - Add a column 𝑓% (frequency) indicating how many times each number appears.

df_1["Frecuency"] = df_1.groupby('Demand of a Product', sort=False).cumcount() + 1
#df_2 = df_1.drop_duplicates()
df_2 = df_1
df_2.head(30)
# Out:
#     Demand of a Product  Frecuency
# 19                   25          1
# 18                   28          1
# 21                   32          1
# 2                    33          1
# 25                   35          1
# 20                   36          1
# 24                   38          1
# 9                    42          1
# 15                   44          1
# 16                   44          2
# 12                   47          1
# 28                   48          1
# 8                    48          2
# 6                    49          1
# 5                    51          1
# 11                   52          1
# 4                    53          1
# 17                   56          1
# 23                   57          1
# 27                   58          1
# 14                   58          2
# 29                   59          1
# 22                   61          1
# 1                    63          1
# 13                   66          1
# 0                    67          1
# 3                    69          1
# 10                   72          1
# 26                   76          1
# 7                    78          1

# %%
# Step 3 - Add Observed relative cumulative frequency column

df_2["Count"] = np.arange(1, len(df_2) + 1)

df_2["Observed Relative Cumulative Frequency"] = df_2["Count"] / len(df)
df_3 = df_2
df_3.head(30)
# Out:
#     Demand of a Product  Frecuency  Count  \
# 19                   25          1      1
# 18                   28          1      2
# 21                   32          1      3
# 2                    33          1      4
# 25                   35          1      5
# 20                   36          1      6
# 24                   38          1      7
# 9                    42          1      8
# 15                   44          1      9
# 16                   44          2     10
# 12                   47          1     11
# 28                   48          1     12
# 8                    48          2     13
# 6                    49          1     14
# 5                    51          1     15
# 11                   52          1     16
# 4                    53          1     17
# 17                   56          1     18
# 23                   57          1     19
# 27                   58          1     20
# 14                   58          2     21
# 29                   59          1     22
# 22                   61          1     23
# 1                    63          1     24
# 13                   66          1     25
# 0                    67          1     26
# 3                    69          1     27
# 10                   72          1     28
# 26                   76          1     29
# 7                    78          1     30
#
#     Observed Relative Cumulative Frequency
# 19                                0.033333
# 18                                0.066667
# 21                                0.100000
# 2                                 0.133333
# 25                                0.166667
# 20                                0.200000
# 24                                0.233333
# 9                                 0.266667
# 15                                0.300000
# 16                                0.333333
# 12                                0.366667
# 28                                0.400000
# 8                                 0.433333
# 6                                 0.466667
# 5                                 0.500000
# 11                                0.533333
# 4                                 0.566667
# 17                                0.600000
# 23                                0.633333
# 27                                0.666667
# 14                                0.700000
# 29                                0.733333
# 22                                0.766667
# 1                                 0.800000
# 13                                0.833333
# 0                                 0.866667
# 3                                 0.900000
# 10                                0.933333
# 26                                0.966667
# 7                                 1.000000

# %%
# Step 4 - Add expected relative cumulative frequency column

normal = statistics.NormalDist(50, 10)

df_3["Expected Relative Cumulative Frequency"] = df_3["Demand of a Product"].apply(lambda x: normal.cdf(x))
df_4 = df_3
df_4.head()
# Out:
#     Demand of a Product  Frecuency  Count  \
# 19                   25          1      1
# 18                   28          1      2
# 21                   32          1      3
# 2                    33          1      4
# 25                   35          1      5
#
#     Observed Relative Cumulative Frequency  \
# 19                                0.033333
# 18                                0.066667
# 21                                0.100000
# 2                                 0.133333
# 25                                0.166667
#
#     Expected Relative Cumulative Frequency
# 19                                0.006210
# 18                                0.013903
# 21                                0.035930
# 2                                 0.044565
# 25                                0.066807

# %%
# Step 5 - Add difference column

df_4["Difference"] = abs(df_4["Observed Relative Cumulative Frequency"]-df_4["Expected Relative Cumulative Frequency"])
df_5 = df_4
df_5.head()
# Out:
#     Demand of a Product  Frecuency  Count  \
# 19                   25          1      1
# 18                   28          1      2
# 21                   32          1      3
# 2                    33          1      4
# 25                   35          1      5
#
#     Observed Relative Cumulative Frequency  \
# 19                                0.033333
# 18                                0.066667
# 21                                0.100000
# 2                                 0.133333
# 25                                0.166667
#
#     Expected Relative Cumulative Frequency  Difference
# 19                                0.006210    0.027124
# 18                                0.013903    0.052763
# 21                                0.035930    0.064070
# 2                                 0.044565    0.088768
# 25                                0.066807    0.099859

# %%
# Step 6 - Get the max of the difference

Dn = max(df_5["Difference"])
print(Dn)
# Out:
# 0.12574688224992636

# %%
# Step 7 - Compare Critical Value of K-S vs Dn Value

cv = 0.24

if (Dn <= cv):
    print("Your data fits with a normal distribution N(50,10)")
else:
    print("Your data DO NOT fits with a normal distribution N(50,10)")
# Out:
# Your data fits with a normal distribution N(50,10)
